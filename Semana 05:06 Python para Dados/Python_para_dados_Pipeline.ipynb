# %% [markdown]
# <a href="https://colab.research.google.com/github/veronicaldfaria/bootcamp-data-analytics/blob/main/Python_para_dados_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import numpy as np
import pandas as pd
import logging

# %%
! python -version
# Out:
# Unknown option: -e
# usage: python3 [option] ... [-c cmd | -m mod | file | -] [arg] ...
# Try `python -h' for more information.

# %% [markdown]
# ### Minha API

# %%
headers = {"chave-api-dados" : "47e19a71230372d2c2ce6c550fd81edf"}

# %% [markdown]
# ### Acesso ao portal da transparência do governo federal playground para a criação da extração

# %%
url = 'https://api.portaldatransparencia.gov.br/api-de-dados/emendas?ano=2022&pagina=2'

resposta_ = requests.get(url, headers=headers)

# %%
resposta_
# Out:
# <Response [200]>

# %%
resposta_.json()
# Out:
# [{'codigoEmenda': '202237790007',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'WALTER ALVES',
#   'nomeAutor': 'WALTER ALVES',
#   'numeroEmenda': '0007',
#   'localidadeDoGasto': 'RIO GRANDE DO NORTE (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '49.912,42',
#   'valorLiquidado': '912,42',
#   'valorPago': '912,42',
#   'valorRestoInscrito': '49.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '49.000,00'},
#  {'codigoEmenda': '202239740002',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ELIAS VAZ',
#   'nomeAutor': 'ELIAS VAZ',
#   'numeroEmenda': '0002',
#   'localidadeDoGasto': 'GOIÁS (UF)',
#   'funcao': 'Saúde',
#   'subfuncao': 'Atenção básica',
#   'valorEmpenhado': '49.993,00',
#   'valorLiquidado': '49.993,00',
#   'valorPago': '49.993,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202228260003',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ERIKA KOKAY',
#   'nomeAutor': 'ERIKA KOKAY',
#   'numeroEmenda': '0003',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '45.000,00',
#   'valorPago': '43.000,00',
#   'valorRestoInscrito': '7.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '7.000,00'},
#  {'codigoEmenda': '202224490009',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'EFRAIM FILHO',
#   'nomeAutor': 'EFRAIM FILHO',
#   'numeroEmenda': '0009',
#   'localidadeDoGasto': 'POÇO DE JOSÉ DE MOURA - PB',
#   'funcao': 'Cultura',
#   'subfuncao': 'Difusão cultural',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '50.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '50.000,00'},
#  {'codigoEmenda': '202241740008',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'TEREZA NELMA',
#   'nomeAutor': 'TEREZA NELMA',
#   'numeroEmenda': '0008',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '50.000,00',
#   'valorPago': '39.140,00',
#   'valorRestoInscrito': '10.860,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '10.860,00'},
#  {'codigoEmenda': '202237560012',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ROSANGELA GOMES',
#   'nomeAutor': 'ROSANGELA GOMES',
#   'numeroEmenda': '0012',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Defesa nacional',
#   'subfuncao': 'Administração geral',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '50.000,00',
#   'valorPago': '50.000,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202240610005',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'PROFESSORA ROSA NEIDE',
#   'nomeAutor': 'PROFESSORA ROSA NEIDE',
#   'numeroEmenda': '0005',
#   'localidadeDoGasto': 'DISTRITO FEDERAL (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '50.000,00',
#   'valorPago': '50.000,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202241420015',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'STYVENSON VALENTIM',
#   'nomeAutor': 'STYVENSON VALENTIM',
#   'numeroEmenda': '0015',
#   'localidadeDoGasto': 'RIO GRANDE DO NORTE (UF)',
#   'funcao': 'Comércio e serviços',
#   'subfuncao': 'Promoção comercial',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '50.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '50.000,00'},
#  {'codigoEmenda': '202230860003',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'DULCE MIRANDA',
#   'nomeAutor': 'DULCE MIRANDA',
#   'numeroEmenda': '0003',
#   'localidadeDoGasto': 'DISTRITO FEDERAL (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '49.375,00',
#   'valorPago': '37.875,00',
#   'valorRestoInscrito': '12.125,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '12.125,00'},
#  {'codigoEmenda': '202239420001',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'CHRIS TONIETTO',
#   'nomeAutor': 'CHRIS TONIETTO',
#   'numeroEmenda': '0001',
#   'localidadeDoGasto': 'RIO DE JANEIRO (UF)',
#   'funcao': 'Saúde',
#   'subfuncao': 'Atenção básica',
#   'valorEmpenhado': '52.593,00',
#   'valorLiquidado': '52.593,00',
#   'valorPago': '52.593,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202239070009',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ALEXANDRE FROTA',
#   'nomeAutor': 'ALEXANDRE FROTA',
#   'numeroEmenda': '0009',
#   'localidadeDoGasto': 'SÃO PAULO - SP',
#   'funcao': 'Defesa nacional',
#   'subfuncao': 'Atenção básica',
#   'valorEmpenhado': '53.314,88',
#   'valorLiquidado': '52.189,34',
#   'valorPago': '44.509,34',
#   'valorRestoInscrito': '8.805,54',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '8.805,54'},
#  {'codigoEmenda': '202212770011',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'WELLINGTON ROBERTO',
#   'nomeAutor': 'WELLINGTON ROBERTO',
#   'numeroEmenda': '0011',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Saúde',
#   'subfuncao': 'Assistência hospitalar e ambulatorial',
#   'valorEmpenhado': '54.141,00',
#   'valorLiquidado': '54.141,00',
#   'valorPago': '54.141,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202240130017',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'GURGEL',
#   'nomeAutor': 'GURGEL',
#   'numeroEmenda': '0017',
#   'localidadeDoGasto': 'APERIBÉ - RJ',
#   'funcao': 'Saúde',
#   'subfuncao': 'Assistência hospitalar e ambulatorial',
#   'valorEmpenhado': '54.320,00',
#   'valorLiquidado': '54.320,00',
#   'valorPago': '54.320,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202224490002',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'EFRAIM FILHO',
#   'nomeAutor': 'EFRAIM FILHO',
#   'numeroEmenda': '0002',
#   'localidadeDoGasto': 'PARAÍBA (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Educação básica',
#   'valorEmpenhado': '60.088,24',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '120.176,48',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202242150001',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'VIVI REIS',
#   'nomeAutor': 'VIVI REIS',
#   'numeroEmenda': '0001',
#   'localidadeDoGasto': 'PARÁ (UF)',
#   'funcao': 'Saúde',
#   'subfuncao': 'Vigilância epidemiológica',
#   'valorEmpenhado': '66.534,00',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '66.534,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '66.534,00'}]

# %%
data1 = resposta_.json()

# %%
pd.DataFrame(data1)
# Out:
#     codigoEmenda   ano                                         tipoEmenda  \
# 0   202237790007  2022  Emenda Individual - Transferências com Finalid...
# 1   202239740002  2022  Emenda Individual - Transferências com Finalid...
# 2   202228260003  2022  Emenda Individual - Transferências com Finalid...
# 3   202224490009  2022  Emenda Individual - Transferências com Finalid...
# 4   202241740008  2022  Emenda Individual - Transferências com Finalid...
# 5   202237560012  2022  Emenda Individual - Transferências com Finalid...
# 6   202240610005  2022  Emenda Individual - Transferências com Finalid...
# 7   202241420015  2022  Emenda Individual - Transferências com Finalid...
# 8   202230860003  2022  Emenda Individual - Transferências com Finalid...
# 9   202239420001  2022  Emenda Individual - Transferências com Finalid...
# 10  202239070009  2022  Emenda Individual - Transferências com Finalid...
# 11  202212770011  2022  Emenda Individual - Transferências com Finalid...
# 12  202240130017  2022  Emenda Individual - Transferências com Finalid...
# 13  202224490002  2022  Emenda Individual - Transferências com Finalid...
# 14  202242150001  2022  Emenda Individual - Transferências com Finalid...
#
#                     autor              nomeAutor numeroEmenda  \
# 0            WALTER ALVES           WALTER ALVES         0007
# 1               ELIAS VAZ              ELIAS VAZ         0002
# 2             ERIKA KOKAY            ERIKA KOKAY         0003
# 3            EFRAIM FILHO           EFRAIM FILHO         0009
# 4            TEREZA NELMA           TEREZA NELMA         0008
# 5         ROSANGELA GOMES        ROSANGELA GOMES         0012
# 6   PROFESSORA ROSA NEIDE  PROFESSORA ROSA NEIDE         0005
# 7      STYVENSON VALENTIM     STYVENSON VALENTIM         0015
# 8           DULCE MIRANDA          DULCE MIRANDA         0003
# 9          CHRIS TONIETTO         CHRIS TONIETTO         0001
# 10        ALEXANDRE FROTA        ALEXANDRE FROTA         0009
# 11     WELLINGTON ROBERTO     WELLINGTON ROBERTO         0011
# 12                 GURGEL                 GURGEL         0017
# 13           EFRAIM FILHO           EFRAIM FILHO         0002
# 14              VIVI REIS              VIVI REIS         0001
#
#              localidadeDoGasto               funcao  \
# 0     RIO GRANDE DO NORTE (UF)             Educação
# 1                   GOIÁS (UF)                Saúde
# 2                     Nacional             Educação
# 3   POÇO DE JOSÉ DE MOURA - PB              Cultura
# 4                     Nacional             Educação
# 5                     Nacional      Defesa nacional
# 6        DISTRITO FEDERAL (UF)             Educação
# 7     RIO GRANDE DO NORTE (UF)  Comércio e serviços
# 8        DISTRITO FEDERAL (UF)             Educação
# 9          RIO DE JANEIRO (UF)                Saúde
# 10              SÃO PAULO - SP      Defesa nacional
# 11                    Nacional                Saúde
# 12                APERIBÉ - RJ                Saúde
# 13                PARAÍBA (UF)             Educação
# 14                   PARÁ (UF)                Saúde
#
#                                 subfuncao valorEmpenhado valorLiquidado  \
# 0                         Ensino superior      49.912,42         912,42
# 1                          Atenção básica      49.993,00      49.993,00
# 2                         Ensino superior      50.000,00      45.000,00
# 3                        Difusão cultural      50.000,00           0,00
# 4                         Ensino superior      50.000,00      50.000,00
# 5                     Administração geral      50.000,00      50.000,00
# 6                         Ensino superior      50.000,00      50.000,00
# 7                      Promoção comercial      50.000,00           0,00
# 8                         Ensino superior      50.000,00      49.375,00
# 9                          Atenção básica      52.593,00      52.593,00
# 10                         Atenção básica      53.314,88      52.189,34
# 11  Assistência hospitalar e ambulatorial      54.141,00      54.141,00
# 12  Assistência hospitalar e ambulatorial      54.320,00      54.320,00
# 13                        Educação básica      60.088,24           0,00
# 14              Vigilância epidemiológica      66.534,00           0,00
#
#     valorPago valorRestoInscrito valorRestoCancelado valorRestoPago
# 0      912,42          49.000,00                0,00      49.000,00
# 1   49.993,00               0,00                0,00           0,00
# 2   43.000,00           7.000,00                0,00       7.000,00
# 3        0,00          50.000,00                0,00      50.000,00
# 4   39.140,00          10.860,00                0,00      10.860,00
# 5   50.000,00               0,00                0,00           0,00
# 6   50.000,00               0,00                0,00           0,00
# 7        0,00          50.000,00                0,00      50.000,00
# 8   37.875,00          12.125,00                0,00      12.125,00
# 9   52.593,00               0,00                0,00           0,00
# 10  44.509,34           8.805,54                0,00       8.805,54
# 11  54.141,00               0,00                0,00           0,00
# 12  54.320,00               0,00                0,00           0,00
# 13       0,00         120.176,48                0,00           0,00
# 14       0,00          66.534,00                0,00      66.534,00

# %%
data2 = resposta_.json()

# %%
url = 'https://api.portaldatransparencia.gov.br/api-de-dados/emendas?ano=2022&pagina='

# %%
# Emendas página até 408

list_urls = [url + str(i) for i in range(1, 409)]

# %%
list_urls[:2]
# Out:
# ['https://api.portaldatransparencia.gov.br/api-de-dados/emendas?ano=2022&pagina=1',
#  'https://api.portaldatransparencia.gov.br/api-de-dados/emendas?ano=2022&pagina=2']

# %%
def run_request(url_):
  resposta = requests.get(url_, headers=headers)
  return resposta.json()

# %%
# passando a lista para um array
arr_urls = np.asarray(list_urls)

# %%
vec_run = np.vectorize(run_request)

arr_responses = vec_run(arr_urls)

# %%
arr_responses = arr_responses.tolist()

# %%
arr_responses[1]
# Out:
# [{'codigoEmenda': '202237790007',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'WALTER ALVES',
#   'nomeAutor': 'WALTER ALVES',
#   'numeroEmenda': '0007',
#   'localidadeDoGasto': 'RIO GRANDE DO NORTE (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '49.912,42',
#   'valorLiquidado': '912,42',
#   'valorPago': '912,42',
#   'valorRestoInscrito': '49.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '49.000,00'},
#  {'codigoEmenda': '202239740002',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ELIAS VAZ',
#   'nomeAutor': 'ELIAS VAZ',
#   'numeroEmenda': '0002',
#   'localidadeDoGasto': 'GOIÁS (UF)',
#   'funcao': 'Saúde',
#   'subfuncao': 'Atenção básica',
#   'valorEmpenhado': '49.993,00',
#   'valorLiquidado': '49.993,00',
#   'valorPago': '49.993,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202228260003',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ERIKA KOKAY',
#   'nomeAutor': 'ERIKA KOKAY',
#   'numeroEmenda': '0003',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '45.000,00',
#   'valorPago': '43.000,00',
#   'valorRestoInscrito': '7.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '7.000,00'},
#  {'codigoEmenda': '202224490009',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'EFRAIM FILHO',
#   'nomeAutor': 'EFRAIM FILHO',
#   'numeroEmenda': '0009',
#   'localidadeDoGasto': 'POÇO DE JOSÉ DE MOURA - PB',
#   'funcao': 'Cultura',
#   'subfuncao': 'Difusão cultural',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '50.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '50.000,00'},
#  {'codigoEmenda': '202241740008',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'TEREZA NELMA',
#   'nomeAutor': 'TEREZA NELMA',
#   'numeroEmenda': '0008',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '50.000,00',
#   'valorPago': '39.140,00',
#   'valorRestoInscrito': '10.860,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '10.860,00'},
#  {'codigoEmenda': '202237560012',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ROSANGELA GOMES',
#   'nomeAutor': 'ROSANGELA GOMES',
#   'numeroEmenda': '0012',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Defesa nacional',
#   'subfuncao': 'Administração geral',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '50.000,00',
#   'valorPago': '50.000,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202240610005',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'PROFESSORA ROSA NEIDE',
#   'nomeAutor': 'PROFESSORA ROSA NEIDE',
#   'numeroEmenda': '0005',
#   'localidadeDoGasto': 'DISTRITO FEDERAL (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '50.000,00',
#   'valorPago': '50.000,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202241420015',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'STYVENSON VALENTIM',
#   'nomeAutor': 'STYVENSON VALENTIM',
#   'numeroEmenda': '0015',
#   'localidadeDoGasto': 'RIO GRANDE DO NORTE (UF)',
#   'funcao': 'Comércio e serviços',
#   'subfuncao': 'Promoção comercial',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '50.000,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '50.000,00'},
#  {'codigoEmenda': '202230860003',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'DULCE MIRANDA',
#   'nomeAutor': 'DULCE MIRANDA',
#   'numeroEmenda': '0003',
#   'localidadeDoGasto': 'DISTRITO FEDERAL (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Ensino superior',
#   'valorEmpenhado': '50.000,00',
#   'valorLiquidado': '49.375,00',
#   'valorPago': '37.875,00',
#   'valorRestoInscrito': '12.125,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '12.125,00'},
#  {'codigoEmenda': '202239420001',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'CHRIS TONIETTO',
#   'nomeAutor': 'CHRIS TONIETTO',
#   'numeroEmenda': '0001',
#   'localidadeDoGasto': 'RIO DE JANEIRO (UF)',
#   'funcao': 'Saúde',
#   'subfuncao': 'Atenção básica',
#   'valorEmpenhado': '52.593,00',
#   'valorLiquidado': '52.593,00',
#   'valorPago': '52.593,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202239070009',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'ALEXANDRE FROTA',
#   'nomeAutor': 'ALEXANDRE FROTA',
#   'numeroEmenda': '0009',
#   'localidadeDoGasto': 'SÃO PAULO - SP',
#   'funcao': 'Defesa nacional',
#   'subfuncao': 'Atenção básica',
#   'valorEmpenhado': '53.314,88',
#   'valorLiquidado': '52.189,34',
#   'valorPago': '44.509,34',
#   'valorRestoInscrito': '8.805,54',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '8.805,54'},
#  {'codigoEmenda': '202212770011',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'WELLINGTON ROBERTO',
#   'nomeAutor': 'WELLINGTON ROBERTO',
#   'numeroEmenda': '0011',
#   'localidadeDoGasto': 'Nacional',
#   'funcao': 'Saúde',
#   'subfuncao': 'Assistência hospitalar e ambulatorial',
#   'valorEmpenhado': '54.141,00',
#   'valorLiquidado': '54.141,00',
#   'valorPago': '54.141,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202240130017',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'GURGEL',
#   'nomeAutor': 'GURGEL',
#   'numeroEmenda': '0017',
#   'localidadeDoGasto': 'APERIBÉ - RJ',
#   'funcao': 'Saúde',
#   'subfuncao': 'Assistência hospitalar e ambulatorial',
#   'valorEmpenhado': '54.320,00',
#   'valorLiquidado': '54.320,00',
#   'valorPago': '54.320,00',
#   'valorRestoInscrito': '0,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202224490002',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'EFRAIM FILHO',
#   'nomeAutor': 'EFRAIM FILHO',
#   'numeroEmenda': '0002',
#   'localidadeDoGasto': 'PARAÍBA (UF)',
#   'funcao': 'Educação',
#   'subfuncao': 'Educação básica',
#   'valorEmpenhado': '60.088,24',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '120.176,48',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '0,00'},
#  {'codigoEmenda': '202242150001',
#   'ano': 2022,
#   'tipoEmenda': 'Emenda Individual - Transferências com Finalidade Definida',
#   'autor': 'VIVI REIS',
#   'nomeAutor': 'VIVI REIS',
#   'numeroEmenda': '0001',
#   'localidadeDoGasto': 'PARÁ (UF)',
#   'funcao': 'Saúde',
#   'subfuncao': 'Vigilância epidemiológica',
#   'valorEmpenhado': '66.534,00',
#   'valorLiquidado': '0,00',
#   'valorPago': '0,00',
#   'valorRestoInscrito': '66.534,00',
#   'valorRestoCancelado': '0,00',
#   'valorRestoPago': '66.534,00'}]

# %%
reposta = np.concatenate(arr_responses).tolist()

# %%
df = pd.DataFrame(reposta)

# %%
df.head()
# Out:
#    codigoEmenda   ano                                         tipoEmenda  \
# 0  202250170002  2022                                 Emenda de Comissão
# 1  202281000305  2022                                  Emenda de Relator
# 2  202237370006  2022  Emenda Individual - Transferências com Finalid...
# 3  202240600003  2022  Emenda Individual - Transferências com Finalid...
# 4  202229250004  2022  Emenda Individual - Transferências com Finalid...
#
#                         autor                   nomeAutor numeroEmenda  \
# 0  COM. FINANCAS E TRIBUTACAO  COM. FINANCAS E TRIBUTACAO         0002
# 1               RELATOR GERAL               RELATOR GERAL         0305
# 2               ORLANDO SILVA               ORLANDO SILVA         0006
# 3              LUIZAO GOULART              LUIZAO GOULART         0003
# 4              CARMEN ZANOTTO              CARMEN ZANOTTO         0004
#
#         localidadeDoGasto              funcao  \
# 0                Nacional       Administração
# 1                Nacional  Assistência social
# 2          SÃO PAULO (UF)               Saúde
# 3  RIO BRANCO DO SUL - PR               Saúde
# 4   DISTRITO FEDERAL (UF)            Educação
#
#                                subfuncao valorEmpenhado valorLiquidado  \
# 0                        Ensino superior       3.560,00       3.560,00
# 1                 Alimentação e nutrição       8.037,30       8.037,30
# 2              Vigilância epidemiológica      10.675,00           0,00
# 3  Assistência hospitalar e ambulatorial      11.268,00      11.268,00
# 4                        Ensino superior      30.000,00      28.500,00
#
#    valorPago valorRestoInscrito valorRestoCancelado valorRestoPago
# 0       0,00           3.560,00                0,00       3.560,00
# 1   8.037,30               0,00                0,00           0,00
# 2       0,00          10.675,00                0,00      10.675,00
# 3  11.268,00               0,00                0,00           0,00
# 4  21.500,00          10.000,00                0,00       7.000,00

# %%
df_area = df[['funcao', 'valorEmpenhado']]
df_area.loc[:, 'valorEmpenhado'] = df_area['valorEmpenhado'].str.replace('.', '').str.replace(',', '.').astype(np.float64)

# %%
df_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6108 entries, 0 to 6107
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   funcao          6108 non-null   object
#  1   valorEmpenhado  6108 non-null   object
# dtypes: object(2)
# memory usage: 95.6+ KB

# %%
agg_area = df_area.groupby('funcao').sum('valorEmpenhado')

# %%
agg_area
# Out:
# Empty DataFrame
# Columns: []
# Index: [Administração, Agricultura, Assistência social, Ciência e Tecnologia, Comunicações, Comércio e serviços, Cultura, Defesa nacional, Desporto e lazer, Direitos da cidadania, Educação, Encargos especiais, Gestão ambiental, Habitação, Indústria, Múltiplo, Organização agrária, Previdência social, Relações exteriores, Saúde, Segurança pública, Trabalho, Transporte, Urbanismo]

# %%
1.380082e+09/23670334710.190002
# Out:
# 0.05830428749306528

# %%
df_area = df.loc[:, ['funcao', 'valorEmpenhado']]

# %%
df.columns.tolist()
# Out:
# ['codigoEmenda',
#  'ano',
#  'tipoEmenda',
#  'autor',
#  'nomeAutor',
#  'numeroEmenda',
#  'localidadeDoGasto',
#  'funcao',
#  'subfuncao',
#  'valorEmpenhado',
#  'valorLiquidado',
#  'valorPago',
#  'valorRestoInscrito',
#  'valorRestoCancelado',
#  'valorRestoPago']

# %%
agg_area = agg_area.reset_index()

# %%
agg_area.to_csv('distribuicao_empenho_area_2022.csv')

# %% [markdown]
# ## Criação de ETL e métodos organizados para monitoramento e automação

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
def run_request(url_):
  resposta = requests.get(url_, headers=headers)
  return resposta.json()

# %%
def coletar_dados(url):
  logging.info('Pegou URL para a criação das diferentes URLs criando uma para cada página')
  list_urls = [url + str(i) for i in range(1, 6)]
  arr_urls = np.asarray(list_urls)

  vec_run = np.vectorize(run_request)
  logging.info('Fazendo uma requisição para cada URL')
  arr_responses = vec_run(arr_urls)
  logging.info('Requisições concluídas')
  arr_responses = arr_responses.tolist()
  reposta = np.concatenate(arr_responses).tolist()
  return reposta

# %%
def transformar_dado(dado):
  logging.info('Criando dataframe')
  df = pd.DataFrame(dado)

  logging.info('Selecionando colunas')
  df_area = df[['funcao', 'valorEmpenhado']]

  logging.info('Transformando dado string -> float')
  df_area['valorEmpenhado'] = df_area['valorEmpenhado'].str.replace('.', '').str.replace(',', '.').astype(np.float64)

  logging.info('Transformando dado string -> float')
  agg_area = df_area.groupby('funcao').sum('valorEmpenhado')

  logging.info('Transformando dados para retirar proporção em porcentagem')
  agg_area = agg_area['valorEmpenhado']/df_area['valorEmpenhado'].sum()
  agg_area = agg_area.reset_index()

  return agg_area

# %%
def carga(dado):
  dado.to_csv('distribuicao_empenho_area_2022.csv')

# %%
def etl():
    url = 'https://api.portaldatransparencia.gov.br/api-de-dados/emendas?ano=2022&pagina='
    dado = coletar_dados(url)
    dado = transformar_dado(dado)
    carga(dado)

# %%
etl()
# Out:
# <ipython-input-256-92c97ee33918>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_area['valorEmpenhado'] = df_area['valorEmpenhado'].str.replace('.', '').str.replace(',', '.').astype(np.float64)
